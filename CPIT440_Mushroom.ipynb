# %% [markdown]
#  # <font color=#6d5b57><center> Mushroom Dataset<center></font><br><font color=#394C33><center>CPIT- 440 Project<center></font><img src="http://2jl7cd1oy3fddj8w23cb3brh-wpengine.netdna-ssl.com/wp-content/uploads/2017/02/poisonousmushrooms.inpost.jpg" alt="Mushroom" style= "border: 8px solid #54704B;">

# %% [markdown]
# # <font color=#4D4435> Mushroom Information</font>

# %%
# imports
# %matplotlib inline
import math
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter
import numpy as np
import scipy.stats as ss

# %%
# Read the mushroom dataset
mushroom = pd.read_csv("C:/Users/abooo/Downloads/mushroom.csv") 
mushroom
# Out:
#      cap-shape cap-surface cap-color bruises%3F odor gill-attachment  \
# 0          'x'         's'       'n'        't'  'p'             'f'
# 1          'x'         's'       'y'        't'  'a'             'f'
# 2          'b'         's'       'w'        't'  'l'             'f'
# 3          'x'         'y'       'w'        't'  'p'             'f'
# 4          'x'         's'       'g'        'f'  'n'             'f'
# 5          'x'         'y'       'y'        't'  'a'             'f'
# 6          'b'         's'       'w'        't'  'a'             'f'
# 7          'b'         'y'       'w'        't'  'l'             'f'
# 8          'x'         'y'       'w'        't'  'p'             'f'
# 9          'b'         's'       'y'        't'  'a'             'f'
# 10         'x'         'y'       'y'        't'  'l'             'f'
# 11         'x'         'y'       'y'        't'  'a'             'f'
# 12         'b'         's'       'y'        't'  'a'             'f'
# ...

# %% [markdown]
# ### <font color=#6d5b57> <span>&#183;</span> Number of instance is :</font>

# %%
# Number of instance 
mushroom.shape
# Out:
# (8124, 23)

# %%
# The Head
mushroom.head()
# Out:
#   cap-shape cap-surface cap-color bruises%3F odor gill-attachment  \
# 0       'x'         's'       'n'        't'  'p'             'f'
# 1       'x'         's'       'y'        't'  'a'             'f'
# 2       'b'         's'       'w'        't'  'l'             'f'
# 3       'x'         'y'       'w'        't'  'p'             'f'
# 4       'x'         's'       'g'        'f'  'n'             'f'
#
#   gill-spacing gill-size gill-color stalk-shape  ... stalk-color-above-ring  \
# 0          'c'       'n'        'k'         'e'  ...                    'w'
# 1          'c'       'b'        'k'         'e'  ...                    'w'
# 2          'c'       'b'        'n'         'e'  ...                    'w'
# 3          'c'       'n'        'n'         'e'  ...                    'w'
# 4          'w'       'b'        'k'         't'  ...                    'w'
#
#   stalk-color-below-ring veil-type veil-color ring-number ring-type  \
# ...

# %%
# The Tail
mushroom.tail()
# Out:
#      cap-shape cap-surface cap-color bruises%3F odor gill-attachment  \
# 8119       'k'         's'       'n'        'f'  'n'             'a'
# 8120       'x'         's'       'n'        'f'  'n'             'a'
# 8121       'f'         's'       'n'        'f'  'n'             'a'
# 8122       'k'         'y'       'n'        'f'  'y'             'f'
# 8123       'x'         's'       'n'        'f'  'n'             'a'
#
#      gill-spacing gill-size gill-color stalk-shape  ...  \
# 8119          'c'       'b'        'y'         'e'  ...
# 8120          'c'       'b'        'y'         'e'  ...
# 8121          'c'       'b'        'n'         'e'  ...
# 8122          'c'       'n'        'b'         't'  ...
# 8123          'c'       'b'        'y'         'e'  ...
#
#      stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 8119                    'o'                    'o'       'p'        'o'
# ...

# %% [markdown]
# ### <font color=#6d5b57> <span>&#183;</span> Replace all instance("letters") with appropriate names: </font>

# %%
# To replace all letter with appropriate name 
mushroom['cap-shape'] = mushroom['cap-shape'].replace({"'b'": 'bell', "'c'": 'conical', "'x'": 'convex', "'f'": 'flat', "'k'" : 'knobbed', "'s'" : 'sunken'})

mushroom['cap-surface'] = mushroom['cap-surface'].replace({"'f'": 'fibrous', "'g'": 'grooves', "'y'": 'scaly', "'s'": 'smooth'})

mushroom['cap-color'] = mushroom['cap-color'].replace({"'n'": 'brown', "'b'": 'buff', "'c'": 'cinnamon', "'g'": 'gray',
                                                       "'r'": 'green', "'p'" : 'pink' , "'u'": 'purple', "'e'": 'red',
                                                      "'w'" : 'white' , "'y'": 'yellow'})

mushroom['bruises%3F'] = mushroom['bruises%3F'].replace({"'t'": 'bruises', "'f'": 'no'})

mushroom['odor'] = mushroom['odor'].replace({"'a'": 'almond', "'l'": 'anise', "'c'": 'creosote', "'y'" : 'fishy'
                                             , "'f'" : 'foul' , "'m'" : 'musty' , "'n'" : 'none', "'p'" : 'pungent' , "'s'" : 'spicy'})

mushroom['gill-attachment'] = mushroom['gill-attachment'].replace({"'a'": 'attached', "'d'": 'descending', "'f'" : 'free', 
                                                                  "'n'" : 'notched'})

mushroom['gill-spacing'] = mushroom['gill-spacing'].replace({"'c'": 'close', "'w'": 'crowded', "'d'" : 'distant'}) #7 

mushroom['gill-size'] = mushroom['gill-size'].replace({"'b'": 'broad', "'n'": 'narrow'})

mushroom['gill-color'] = mushroom['gill-color'].replace({"'k'": 'black', "'n'": 'brown', "'b'": 'buff', "'h'": 'chocolate',
                                                       "'g'": 'gray', "'r'" : 'green' , "'o'": 'orange', "'p'": 'pink',
                                                      "'u'" : 'purple' , "'e'": 'red', "'w'" : 'white' , "'y'" : 'yellow'}) #9
mushroom['stalk-shape'] = mushroom['stalk-shape'].replace({"'e'": 'enlarging', "'t'": 'tapering'}) #10

mushroom['stalk-root'] = mushroom['stalk-root'].replace({"'b'": 'bulbous', "'c'": 'club', "'u'" : 'cup' , "'e'" : 'equal' ,
                                                        "'z'" : 'rhizomorphs' , "'r'" : 'rooted' }) #11

mushroom['stalk-surface-above-ring'] = mushroom['stalk-surface-above-ring'].replace({"'f'": 'fibrous', "'y'": 'scaly', "'k'" : 'silky', "'s'" : 'smooth'}) #12
mushroom['stalk-surface-below-ring'] = mushroom['stalk-surface-below-ring'].replace({"'f'": 'fibrous', "'y'": 'scaly', "'k'" : 'silky', "'s'" : 'smooth'}) #13

mushroom['stalk-color-above-ring'] = mushroom['stalk-color-above-ring'].replace({"'n'": 'brown', "'b'": 'buff', "'c'" : 'cinnamon', "'g'" : 'gray'
                                                                                , "'o'" : 'orange' , "'p'" : 'pink' , "'e'" : 'red' , "'w'" : 'white'
                                                                                , "'y'" : 'yellow'}) #14


mushroom['stalk-color-below-ring'] = mushroom['stalk-color-below-ring'].replace({"'n'": 'brown', "'b'": 'buff', "'c'" : 'cinnamon', "'g'" : 'gray'
                                                                                , "'o'" : 'orange' , "'p'" : 'pink' , "'e'" : 'red' , "'w'" : 'white'
                                                                                , "'y'" : 'yellow'}) #15

mushroom['veil-type'] = mushroom['veil-type'].replace({"'p'": 'partial', "'u'": 'universal'}) #16

mushroom['veil-color'] = mushroom['veil-color'].replace({"'n'": 'brown', "'o'": 'orange' , "'w'" : 'white' , "'y'" : 'yellow'}) #17

mushroom['ring-number'] = mushroom['ring-number'].replace({"'n'": 'none', "'o'": 'one' , "'t'" : 'two'}) #18

mushroom['ring-type'] = mushroom['ring-type'].replace({"'c'": 'cobwebby', "'e'": 'evanescent' , "'f'" : 'flaring' , "'l'" : 'large'
                                                      , "'n'" : 'none', "'p'" : 'pendant' , "'s'" : 'sheathing' , "'z'" : 'zone'}) #19

mushroom['spore-print-color'] = mushroom['spore-print-color'].replace({"'k'": 'black', "'n'": 'brown', "'b'": 'buff', "'h'": 'chocolate',"'r'" : 'green',
                                                                       "'o'": 'orange' , "'u'" : 'purple' ,"'w'" : 'white' , "'y'" : 'yellow'}) #20
mushroom['population'] = mushroom['population'].replace({"'a'": 'abundant', "'c'": 'clustered' , "'n'" : 'numerous' , "'s'" : 'scattered', "'v'" : 'several' , "'y'" : 'solitary'}) #21

mushroom['habitat'] = mushroom['habitat'].replace({"'g'": 'grasses', "'l'": 'leaves' , "'m'" : 'meadows' , "'p'" : 'paths', "'u'" : 'urban' , "'w'" : 'waste', "'d'" : 'woods'}) #22
mushroom['class'] = mushroom['class'].replace({"'p'": 'poisnous', "'e'": 'edible'}) #23 -- target

# %%
# To show the dataset after replaced
mushroom
# Out:
#      cap-shape cap-surface cap-color bruises%3F     odor gill-attachment  \
# 0       convex      smooth     brown    bruises  pungent            free
# 1       convex      smooth    yellow    bruises   almond            free
# 2         bell      smooth     white    bruises    anise            free
# 3       convex       scaly     white    bruises  pungent            free
# 4       convex      smooth      gray         no     none            free
# 5       convex       scaly    yellow    bruises   almond            free
# 6         bell      smooth     white    bruises   almond            free
# 7         bell       scaly     white    bruises    anise            free
# 8       convex       scaly     white    bruises  pungent            free
# 9         bell      smooth    yellow    bruises   almond            free
# 10      convex       scaly    yellow    bruises    anise            free
# 11      convex       scaly    yellow    bruises   almond            free
# ...

# %% [markdown]
# ### <font color=#6d5b57> <span>&#183;</span> The missing value in Mushroom dataset :</font>

# %%
# The missing value in mushroom dataset represent as >>> ? <<<
from numpy import nan
Missing_Value = mushroom.replace("?", nan)

# %%
# To show if there are missing value and how many times appears
Missing_Value.isnull().sum(axis=0)
# Out:
# cap-shape                      0
# cap-surface                    0
# cap-color                      0
# bruises%3F                     0
# odor                           0
# gill-attachment                0
# gill-spacing                   0
# gill-size                      0
# gill-color                     0
# stalk-shape                    0
# stalk-root                  2480
# stalk-surface-above-ring       0
# stalk-surface-below-ring       0
# stalk-color-above-ring         0
# stalk-color-below-ring         0
# veil-type                      0
# veil-color                     0
# ring-number                    0
# ring-type                      0
# spore-print-color              0
# population                     0
# habitat                        0
# class                          0
# dtype: int64

# %% [markdown]
# ### <font color=blue >Yes, the mushroom dataset has missing value equal <b>2480</b> in Stalk-root and represented as > ? < </font>

# %% [markdown]
# ### <font color=#6d5b57> <span>&#183;</span> The data type of mushroom dateset :</font>

# %%
# To know the data type of our dataset
mushroom.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8124 entries, 0 to 8123
# Data columns (total 23 columns):
# cap-shape                   8124 non-null object
# cap-surface                 8124 non-null object
# cap-color                   8124 non-null object
# bruises%3F                  8124 non-null object
# odor                        8124 non-null object
# gill-attachment             8124 non-null object
# gill-spacing                8124 non-null object
# gill-size                   8124 non-null object
# gill-color                  8124 non-null object
# stalk-shape                 8124 non-null object
# stalk-root                  8124 non-null object
# stalk-surface-above-ring    8124 non-null object
# stalk-surface-below-ring    8124 non-null object
# stalk-color-above-ring      8124 non-null object
# stalk-color-below-ring      8124 non-null object
# veil-type                   8124 non-null object
# veil-color                  8124 non-null object
# ...

# %% [markdown]
# ### <font color= blue >Object in Dtype means the attribute is categorical. So, we have categorical attributes </font>

# %% [markdown]
# ### <font color=#6d5b57> <span>&#183;</span> Show the categories for each attribute : </font>

# %%
mushroom['cap-shape'].value_counts()
# Out:
# convex     3656
# flat       3152
# knobbed     828
# bell        452
# sunken       32
# conical       4
# Name: cap-shape, dtype: int64

# %%
mushroom['cap-surface'].value_counts()
# Out:
# scaly      3244
# smooth     2556
# fibrous    2320
# grooves       4
# Name: cap-surface, dtype: int64

# %%
mushroom['cap-color'].value_counts()
# Out:
# brown       2284
# gray        1840
# red         1500
# yellow      1072
# white       1040
# buff         168
# pink         144
# cinnamon      44
# purple        16
# green         16
# Name: cap-color, dtype: int64

# %%
mushroom['bruises%3F'].value_counts()
# Out:
# no         4748
# bruises    3376
# Name: bruises%3F, dtype: int64

# %%
mushroom['odor'].value_counts()
# Out:
# none        3528
# foul        2160
# fishy        576
# spicy        576
# anise        400
# almond       400
# pungent      256
# creosote     192
# musty         36
# Name: odor, dtype: int64

# %%
mushroom['gill-attachment'].value_counts()
# Out:
# free        7914
# attached     210
# Name: gill-attachment, dtype: int64

# %%
mushroom['gill-spacing'].value_counts()
# Out:
# close      6812
# crowded    1312
# Name: gill-spacing, dtype: int64

# %%
mushroom['gill-size'].value_counts()
# Out:
# broad     5612
# narrow    2512
# Name: gill-size, dtype: int64

# %%
mushroom['gill-color'].value_counts()
# Out:
# buff         1728
# pink         1492
# white        1202
# brown        1048
# gray          752
# chocolate     732
# purple        492
# black         408
# red            96
# yellow         86
# orange         64
# green          24
# Name: gill-color, dtype: int64

# %%
mushroom['stalk-shape'].value_counts()
# Out:
# tapering     4608
# enlarging    3516
# Name: stalk-shape, dtype: int64

# %%
mushroom['stalk-root'].value_counts()
# Out:
# bulbous    3776
# ?          2480
# equal      1120
# club        556
# rooted      192
# Name: stalk-root, dtype: int64

# %%
mushroom['stalk-surface-above-ring'].value_counts()
# Out:
# smooth     5176
# silky      2372
# fibrous     552
# scaly        24
# Name: stalk-surface-above-ring, dtype: int64

# %%
mushroom['stalk-surface-below-ring'].value_counts()
# Out:
# smooth     4936
# silky      2304
# fibrous     600
# scaly       284
# Name: stalk-surface-below-ring, dtype: int64

# %%
mushroom['stalk-color-above-ring'].value_counts()
# Out:
# white       4464
# pink        1872
# gray         576
# brown        448
# buff         432
# orange       192
# red           96
# cinnamon      36
# yellow         8
# Name: stalk-color-above-ring, dtype: int64

# %%
mushroom['stalk-color-below-ring'].value_counts()
# Out:
# white       4384
# pink        1872
# gray         576
# brown        512
# buff         432
# orange       192
# red           96
# cinnamon      36
# yellow        24
# Name: stalk-color-below-ring, dtype: int64

# %%
mushroom['veil-type'].value_counts()
# Out:
# partial    8124
# Name: veil-type, dtype: int64

# %%
mushroom['veil-color'].value_counts()
# Out:
# white     7924
# orange      96
# brown       96
# yellow       8
# Name: veil-color, dtype: int64

# %%
mushroom['ring-number'].value_counts()
# Out:
# one     7488
# two      600
# none      36
# Name: ring-number, dtype: int64

# %%
mushroom['ring-type'].value_counts()
# Out:
# pendant       3968
# evanescent    2776
# large         1296
# flaring         48
# none            36
# Name: ring-type, dtype: int64

# %%
mushroom['spore-print-color'].value_counts()
# Out:
# white        2388
# brown        1968
# black        1872
# chocolate    1632
# green          72
# purple         48
# buff           48
# yellow         48
# orange         48
# Name: spore-print-color, dtype: int64

# %%
mushroom['population'].value_counts()
# Out:
# several      4040
# solitary     1712
# scattered    1248
# numerous      400
# abundant      384
# clustered     340
# Name: population, dtype: int64

# %%
mushroom['habitat'].value_counts()
# Out:
# woods      3148
# grasses    2148
# paths      1144
# leaves      832
# urban       368
# meadows     292
# waste       192
# Name: habitat, dtype: int64

# %%
mushroom['class'].value_counts()
# Out:
# edible      4208
# poisnous    3916
# Name: class, dtype: int64

# %% [markdown]
# ### <font color=#6d5b57> <span>&#183;</span> Check if the Dataset balanced or not:</font>

# %%
# to check if the dataset is balenced or not by using the target
mushroom['class'].value_counts()
# Out:
# edible      4208
# poisnous    3916
# Name: class, dtype: int64

# %% [markdown]
# ### <font color= blue>The Dataset balanced </font>

# %% [markdown]
# ### <font color=#6d5b57> <span>&#183;</span> The visualization of mushroom dataset using histogram:</font>

# %%
# To show the visualization for each attribute 
mushroom["cap-shape"].value_counts().plot(kind='bar')
plt.title('Cap Shape Histogram')
plt.show()
mushroom["cap-surface"].value_counts().plot(kind='bar')
plt.title('Cap Surface Histogram')
plt.show()
mushroom["cap-color"].value_counts().plot(color= ['#7c5636', 'gray', '#e02929', 'yellow', '#e3e3e3',
                                                  '#dbd000', '#ef7676', '#d2691e', 'purple','green'],kind='bar')
plt.title('Cap Color Histogram')
plt.show()
#----------------------------------------------------
mushroom["bruises%3F"].value_counts().plot(color= ['red', 'green'] , kind = 'bar')
plt.title('Bruises Histogram')
plt.show()
#----------------------------------------------------
mushroom["odor"].value_counts().plot( kind = 'bar')
plt.title('Odor Histogram')
plt.show()
#----------------------------------------------------
mushroom["gill-attachment"].value_counts().plot(color= [ '#0f690c', '#912727'] , kind = 'bar')
plt.title('Gill Attachment Histogram')
plt.show()
mushroom["gill-spacing"].value_counts().plot( kind = 'bar')
plt.title('Gill Spacing Histogram')
plt.show()
mushroom["gill-size"].value_counts().plot( kind = 'bar')
plt.title('Gill Size Histogram')
plt.show()
mushroom["gill-color"].value_counts().plot(color= ['#dbd000', '#ef7676', '#e3e3e3', '#7c5636', 'gray',  'brown' ,
                                                   'purple', 'black' , 'red', 'yellow', 'orange', 'green'],kind='bar')
plt.title('Gill Colors Histogram')
plt.show()
#----------------------------------------------------
mushroom["stalk-shape"].value_counts().plot(kind='bar')
plt.title('Stalk Shape Histogram')
plt.show()
mushroom["stalk-root"].value_counts().plot(kind='bar')
plt.title('Stalk Root Histogram')
plt.show()
#----------------------------------------------------
mushroom["stalk-surface-above-ring"].value_counts().plot(kind='bar')
plt.title('Stalk Surface Above Ring Histogram')
plt.show()
mushroom["stalk-surface-below-ring"].value_counts().plot(kind='bar')
plt.title('Stalk Surface Below Ring Histogram')
plt.show()
mushroom["stalk-color-above-ring"].value_counts().plot(color= ['#e3e3e3', '#ef7676', 'gray', '#7c5636', '#dbd000', 'orange','red', '#d2691e', 'yellow'
],kind='bar')

plt.title('Stalk Color Above Ring Histogram')
plt.show()
mushroom["stalk-color-below-ring"].value_counts().plot(color= ['#e3e3e3', '#ef7676', 'gray', '#7c5636', '#dbd000', 'orange','red', '#d2691e', 'yellow'
],kind='bar')

plt.title('Stalk Color Below Ring Histogram')
plt.show()
#----------------------------------------------------
mushroom["veil-type"].value_counts().plot(kind='bar')
plt.title('Veil Type Histogram')
plt.show()
mushroom["veil-color"].value_counts().plot(color= ['#e3e3e3', '#7c5636', 'orange', 'yellow'],kind='bar')
plt.title('Veil Color Histogram')
plt.show()
#----------------------------------------------------
mushroom["ring-number"].value_counts().plot(kind='bar')
plt.title('Ring Number Histogram')
plt.show()
mushroom["ring-type"].value_counts().plot(kind='bar')
plt.title('Ring Type Histogram')
plt.show()
#----------------------------------------------------
mushroom["spore-print-color"].value_counts().plot(color= ['#e3e3e3', '#7c5636', 'black', 'brown', 'green', 'purple', 'orange', '#dbd000', 'yellow'],kind='bar')
plt.title('Spore Print Color Histogram')
plt.show()
#----------------------------------------------------
mushroom["population"].value_counts().plot(kind='bar')
plt.title('Population Histogram')
plt.show()
mushroom["habitat"].value_counts().plot(kind='bar')
plt.title('Habitat Histogram')
plt.show()
#----------------------------------------------------
mushroom["class"].value_counts().plot(color= ['green', 'red'],kind='bar')
plt.title('Class Histogram')
plt.show()

# %% [markdown]
# ### <font color=#6d5b57> <span>&#183;</span> Calculate the correlation of mushroom dataset: THEIL's U </font>

# %%
def conditional_entropy(x,y):
    # entropy of x given y
    y_counter = Counter(y)
    xy_counter = Counter(list(zip(x,y)))
    total_occurrences = sum(y_counter.values())
    entropy = 0
    for xy in xy_counter.keys():
        p_xy = xy_counter[xy] / total_occurrences
        p_y = y_counter[xy[1]] / total_occurrences
        entropy += p_xy * math.log(p_y/p_xy)
    return entropy
#-----------------------------------------------------------
def theil_u(x,y):
    s_xy = conditional_entropy(x,y)
    x_counter = Counter(x)
    total_occurrences = sum(x_counter.values())
    p_x = list(map(lambda n: n/total_occurrences, x_counter.values()))
    s_x = ss.entropy(p_x)
    if s_x == 0:
        return 1
    else:
        return (s_x - s_xy) / s_x

# %% [markdown]
# ### <font color=#6d5b57> <span>&#183;</span> Correlation of mushroom dataset :</font>

# %%
x=['cap-shape','cap-surface','cap-color','bruises%3F','odor','gill-attachment','gill-spacing','gill-size',
   'gill-color','stalk-shape','stalk-root','stalk-surface-above-ring','stalk-surface-below-ring',
  'stalk-color-above-ring','stalk-color-below-ring','veil-type','veil-color','ring-number','ring-type',
  'spore-print-color','population','habitat','class']

for i in range(0,23):
    theilu = pd.DataFrame(index=[x[i]],columns=mushroom.columns)
    columns = mushroom.columns
    for j in range(0,len(columns)):
        u = theil_u(mushroom[x[i]].tolist(),mushroom[columns[j]].tolist())
        theilu.loc[:,columns[j]] = u
    theilu.fillna(value=np.nan,inplace=True)
    plt.figure(figsize=(20,1))
    ax= sns.heatmap(theilu,annot=True,fmt='.2f')
    plt.show()

# %% [markdown]
# # <font color=#4D4435> Data preprocessing</font>

# %% [markdown]
# ### <font color=#6d5b57> 1. Check the duplication :</font>

# %%
dup_rows = mushroom[mushroom.duplicated(subset=None, keep='first')]
dup_rows
# Out:
# Empty DataFrame
# Columns: [cap-shape, cap-surface, cap-color, bruises%3F, odor, gill-attachment, gill-spacing, gill-size, gill-color, stalk-shape, stalk-root, stalk-surface-above-ring, stalk-surface-below-ring, stalk-color-above-ring, stalk-color-below-ring, veil-type, veil-color, ring-number, ring-type, spore-print-color, population, habitat, class]
# Index: []
#
# [0 rows x 23 columns]

# %% [markdown]
# ### <font color=blue>Mushroom dataset has no duplicates.

# %% [markdown]
# ### <font color=#6d5b57> 2. Splitting into train and test sets:</font>

# %%
# Step 2 then split into train & test 
from sklearn.model_selection import train_test_split
train_set, test_set = train_test_split(mushroom, test_size=0.2, random_state=42,stratify=mushroom['class'])

# %%
# show the instance of each train & test
print(train_set.shape,test_set.shape)
# Out:
# (6499, 23) (1625, 23)

# %%
# Now we will handle the train from missing value so save in new var
train_clean = train_set

# %% [markdown]
# ### <font color=#6d5b57> 3. Handling missing values:</font>

# %%
train_clean["stalk-root"]
# Out:
# 5249    bulbous
# 5781          ?
# 7586          ?
# 6181          ?
# 7338          ?
# 3760    bulbous
# 409      rooted
# 5103    bulbous
# 3523    bulbous
# 1050    bulbous
# 5578    bulbous
# 6239          ?
# 7319          ?
# 5225    bulbous
# 1519      equal
# 880     bulbous
# 5562          ?
# 3922    bulbous
# 4295    bulbous
# 7464          ?
# 4762    bulbous
# 2655    bulbous
# 4894    bulbous
# 2076    bulbous
# 3926    bulbous
# 4754    bulbous
# 6758          ?
# 2686    bulbous
# 6574          ?
# 7776          ?
#          ...
# 5979    bulbous
# 2667    bulbous
# 5588          ?
# 2075       club
# 6947          ?
# 2997    bulbous
# 1889    bulbous
# 7447          ?
# 1979    bulbous
# 6488          ?
# 3744    bulbous
# 7683          ?
# 1779      equal
# 5561    bulbous
# 1034      equal
# 2612    bulbous
# 4925    bulbous
# 1313      equal
# 3309    bulbous
# 7362          ?
# 2754    bulbous
# 2767    bulbous
# 5419    bulbous
# 620      rooted
# ...

# %%
# fill in the missing value 
train_clean["stalk-root"].fillna('missing', inplace=True)
# Out:
# C:\Users\abooo\Anaconda3\lib\site-packages\pandas\core\generic.py:6130: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)

# %%
# To show the mushroom dataset after fill missing value <<< remove missing value >>>
train_clean.isnull().sum(axis=0)
# Out:
# cap-shape                   0
# cap-surface                 0
# cap-color                   0
# bruises%3F                  0
# odor                        0
# gill-attachment             0
# gill-spacing                0
# gill-size                   0
# gill-color                  0
# stalk-shape                 0
# stalk-root                  0
# stalk-surface-above-ring    0
# stalk-surface-below-ring    0
# stalk-color-above-ring      0
# stalk-color-below-ring      0
# veil-type                   0
# veil-color                  0
# ring-number                 0
# ring-type                   0
# spore-print-color           0
# population                  0
# habitat                     0
# class                       0
# dtype: int64

# %% [markdown]
# ### <font color=#6d5b57>4. Handling the catogrical attribute:</font>

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# Convert the categorical features to numeric: solution by use labalEncoder.
labelEncoder = LabelEncoder()
Clean_mushroom= train_clean.apply(labelEncoder.fit_transform)# we can save the converted in new var
Clean_mushroom
# Out:
#       cap-shape  cap-surface  cap-color  bruises%3F  odor  gill-attachment  \
# 5249          3            2          9           1     4                1
# 5781          2            3          5           0     6                1
# 7586          0            3          3           1     6                1
# 6181          3            3          0           1     8                1
# 7338          4            2          0           1     4                1
# 3760          3            2          7           0     6                1
# 409           2            2          0           0     1                1
# 5103          2            3          8           0     4                1
# 3523          3            0          3           0     6                1
# 1050          2            0          7           0     6                1
# 5578          2            2          2           1     6                1
# ...

# %% [markdown]
# ### <font color=#6d5b57>5. Explore the Outliers :</font>

# %%
# Calculate the IQR of all the numerical attributes
Q1 = Clean_mushroom.quantile(0.25)
Q3 = Clean_mushroom.quantile(0.75)
IQR = Q3 - Q1
IQR
# Out:
# cap-shape                   1.0
# cap-surface                 3.0
# cap-color                   8.0
# bruises%3F                  1.0
# odor                        2.0
# gill-attachment             0.0
# gill-spacing                0.0
# gill-size                   1.0
# gill-color                  5.0
# stalk-shape                 1.0
# stalk-root                  1.0
# stalk-surface-above-ring    1.0
# stalk-surface-below-ring    1.0
# stalk-color-above-ring      2.0
# stalk-color-below-ring      2.0
# veil-type                   0.0
# veil-color                  0.0
# ring-number                 0.0
# ring-type                   4.0
# spore-print-color           6.0
# population                  1.0
# habitat                     6.0
# class                       1.0
# dtype: float64

# %%
# Check if we have the outlire (false>> mean don't have , true>> mean we have outlier)
outlier = (Clean_mushroom.min() < Q1-1.5*IQR) | (Clean_mushroom.max() > Q3+1.5*IQR)
outlier
# Out:
# cap-shape                    True
# cap-surface                 False
# cap-color                   False
# bruises%3F                  False
# odor                         True
# gill-attachment              True
# gill-spacing                 True
# gill-size                   False
# gill-color                  False
# stalk-shape                 False
# stalk-root                   True
# stalk-surface-above-ring     True
# stalk-surface-below-ring     True
# stalk-color-above-ring       True
# stalk-color-below-ring       True
# veil-type                   False
# veil-color                   True
# ring-number                  True
# ring-type                   False
# spore-print-color           False
# population                   True
# habitat                     False
# class                       False
# dtype: bool

# %%
# To print the number of rows that include outlier in any column
outlier_index = ((Clean_mushroom < (Q1 - 1.5 * IQR)) |(Clean_mushroom > (Q3 + 1.5 * IQR))).any(axis=1)
print(outlier_index.value_counts())
# Out:
# True     3375
# False    3124
# dtype: int64

# %%
# identify outliers in the training dataset using Local Outlier Factor method
from sklearn.neighbors import LocalOutlierFactor
lof = LocalOutlierFactor()
yhat = lof.fit_predict(Clean_mushroom)
for i in yhat:
    if yhat[i] == -1:      
        print ("true")
print(yhat)
# Out:
# [1 1 1 ... 1 1 1]

# %%
# identify outliers in the training dataset using One-class SVM method
from sklearn.svm import OneClassSVM
ee = OneClassSVM(nu=0.01)
yhat = ee.fit_predict(Clean_mushroom)
print(yhat)

for i in yhat:
    if yhat[i] == -1:      
        print ("true")
# Out:
# [1 1 1 ... 1 1 1]

# %% [markdown]
# ### <font color= blue >Based on the output, there is no outilers by using One-class SVM and local Outlier Factor </font>

# %%
# To arrange the index order
Clean_mushroom.reset_index(drop=True,inplace=True)
Clean_mushroom
# Out:
#       cap-shape  cap-surface  cap-color  bruises%3F  odor  gill-attachment  \
# 0             3            2          9           1     4                1
# 1             2            3          5           0     6                1
# 2             0            3          3           1     6                1
# 3             3            3          0           1     8                1
# 4             4            2          0           1     4                1
# 5             3            2          7           0     6                1
# 6             2            2          0           0     1                1
# 7             2            3          8           0     4                1
# 8             3            0          3           0     6                1
# 9             2            0          7           0     6                1
# 10            2            2          2           1     6                1
# ...

# %%
Clean_mushroom.to_csv('mushroom_cleand.csv', index=False)# save in new file 
# 0 poisonous , 1 edible

# %%
# Reload the clean mushroom dataset
mushroom_Cleaned = pd.read_csv("C:/Users/abooo/Desktop/CPIT 440 WLab/mushroom_cleand.csv") 
mushroom_Cleaned
# Out:
#       cap-shape  cap-surface  cap-color  bruises%3F  odor  gill-attachment  \
# 0             3            2          9           1     4                1
# 1             2            3          5           0     6                1
# 2             0            3          3           1     6                1
# 3             3            3          0           1     8                1
# 4             4            2          0           1     4                1
# 5             3            2          7           0     6                1
# 6             2            2          0           0     1                1
# 7             2            3          8           0     4                1
# 8             3            0          3           0     6                1
# 9             2            0          7           0     6                1
# 10            2            2          2           1     6                1
# ...

# %%
# Reptet for the test set

#2-missing values
mushroom_test = test_set
mushroom_test["stalk-root"].fillna('missing', inplace=True)

#3- Convert the categorical features to numeric: solution 1.
labelEncoder = LabelEncoder()
Clean_mushroomTest= mushroom_test.apply(labelEncoder.fit_transform)# we can save the converted in new var
Clean_mushroomTest

# To arrange the index order
Clean_mushroomTest.reset_index(drop=True,inplace=True)
Clean_mushroomTest.to_csv('test_cleand.csv',index=False)
# Out:
# C:\Users\abooo\Anaconda3\lib\site-packages\pandas\core\generic.py:6130: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)

# %% [markdown]
# # <font color=#4D4435>Model training & test</font>

# %% [markdown]
# ### <font color=##6d5b57>1. Decision Tree - Ghadeer Bahmeed :</font>

# %%
# imports 
from sklearn.tree import DecisionTreeClassifier
from sklearn.feature_selection import RFE
from sklearn.metrics import accuracy_score
from sklearn import metrics 
from sklearn.model_selection import cross_val_predict,cross_validate,cross_val_score
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix,  precision_score, recall_score

X = mushroom_Cleaned.drop('class',axis=1)
Y = mushroom_Cleaned['class']

   # Create for loop with the RFE object and rank each pixel
for i in range (1,23):
    DTC = DecisionTreeClassifier(random_state=42)
    rfe = RFE(estimator=DTC, n_features_to_select=i, step=1)
    rfe.fit(X, Y)

    # Make the prediction and evaluate
    prediction=rfe.predict(X)
    Accuracy= accuracy_score(Y,prediction)

    print("Number of selected features:",rfe.n_features_,"accurecy",Accuracy)
# Out:
# Number of selected features: 1 accurecy 0.869210647791968
# Number of selected features: 2 accurecy 0.9715340821664872
# Number of selected features: 3 accurecy 0.9756885674719188
# Number of selected features: 4 accurecy 0.9756885674719188
# Number of selected features: 5 accurecy 0.98092014156024
# Number of selected features: 6 accurecy 0.9869210647791968
# Number of selected features: 7 accurecy 0.9935374673026619
# Number of selected features: 8 accurecy 0.9996922603477458
# Number of selected features: 9 accurecy 1.0
# Number of selected features: 10 accurecy 1.0
# Number of selected features: 11 accurecy 1.0
# Number of selected features: 12 accurecy 1.0
# Number of selected features: 13 accurecy 1.0
# Number of selected features: 14 accurecy 1.0
# Number of selected features: 15 accurecy 1.0
# Number of selected features: 16 accurecy 1.0
# Number of selected features: 17 accurecy 1.0
# Number of selected features: 18 accurecy 1.0
# ...

# %% [markdown]
# ### <font color= blue >The Accuracy became 100% starting from 9 features. </font>

# %%
def display_scores(scores):
    print("Scores:",scores)
    print("Mean:", scores.mean())
    print("Standard deviation:", scores.std())

# %%
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier

# 1- get X and Y from the dataset
X_train=mushroom_Cleaned.iloc[:,0:10]# The number of feature will give a good accuracy
y_train=mushroom_Cleaned["class"]

# 2- invoke the method
tree = DecisionTreeClassifier()

# 3- Train Decision Tree Classifer
tree = tree.fit(X_train,y_train)

# 4- Predict the response for train dataset
Predictions = tree.predict(X_train)

# 5- To evaluate the Decision Tree model is to use cross-validation
output = cross_validate(tree, X_train, y_train, scoring="neg_mean_squared_error", cv=10, return_estimator =True)
tree_classif_scores = np.sqrt(-output["test_score"])

display_scores(tree_classif_scores)                                                                # Ghadeer Bahmeed
# Out:
# Scores: [0.05547002 0.03922323 0.         0.         0.05547002 0.
#  0.03922323 0.         0.03922323 0.03925343]
# Mean: 0.02678631539268992
# Standard deviation: 0.022660529330469803

# %%
y_train_pred = cross_val_predict(tree, X_train, y_train, cv=10)
scores = cross_val_score(tree, X_train,y_train, cv=10, scoring="accuracy")
print("Accuracy of each fold :\n",scores)
print("Mean of accuracy :",scores.mean()) #Because the dataset unbalnced we can't depended on accuracy
print("Confusion matrix:\n",metrics.confusion_matrix(y_train,y_train_pred))
print("Recall: ",metrics.recall_score(y_train,y_train_pred,average='weighted'))
print("Precision: ",metrics.precision_score(y_train,y_train_pred,average='weighted'))
                                                                                                     # Ghadeer Bahmeed
# Out:
# Accuracy of each fold :
#  [0.99692308 0.99846154 1.         1.         0.99692308 1.
#  0.99846154 1.         0.99846154 0.99845917]
# Mean of accuracy : 0.9987689937181464
# Confusion matrix:
#  [[3365    1]
#  [   7 3126]]
# Recall:  0.9987690413909832
# Precision:  0.9987706626779548

# %% [markdown]
# ### <font color=##6d5b57>2. Gaussian Naive Bayes Classifier - Abeer Ghonaim</font>

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.inspection import permutation_importance

X = mushroom_Cleaned.drop('class',axis=1)
Y = mushroom_Cleaned['class']

gaussian_nb = GaussianNB()
gaussian_nb.fit(X, Y)

imps = permutation_importance(gaussian_nb, X, Y)
print(imps.importances_mean)
# Out:
# [-0.00418526  0.01738729  0.00156947  0.06970303 -0.00098477  0.00892445
#   0.0290814   0.05483921  0.02818895  0.008986   -0.00701646  0.004493
#  -0.00193876 -0.01030928 -0.00753962  0.          0.00843207  0.00446222
#   0.03840591  0.05477766  0.00966303  0.00360055]

# %%
sorted(zip(imps.importances_mean, X.columns), reverse=True)
# Out:
# [(0.06970303123557471, 'bruises%3F'),
#  (0.05483920603169716, 'gill-size'),
#  (0.05477765810124633, 'spore-print-color'),
#  (0.03840590860132327, 'ring-type'),
#  (0.029081397138021204, 'gill-spacing'),
#  (0.02818895214648407, 'gill-color'),
#  (0.017387290352361882, 'cap-surface'),
#  (0.009663025080781628, 'population'),
#  (0.008985997845822413, 'stalk-shape'),
#  (0.008924449915371557, 'gill-attachment'),
#  (0.008432066471764865, 'veil-color'),
#  (0.0044929989229111735, 'stalk-surface-above-ring'),
#  (0.004462224957685756, 'ring-number'),
#  (0.00360055393137404, 'habitat'),
#  (0.001569472226496349, 'cap-color'),
#  (0.0, 'veil-type'),
#  (-0.0009847668872134286, 'odor'),
#  (-0.0019387598092014402, 'stalk-surface-below-ring'),
#  (-0.004185259270657072, 'cap-shape'),
#  (-0.007016464071395645, 'stalk-root'),
#  (-0.0075396214802277315, 'stalk-color-below-ring'),
#  (-0.010309278350515493, 'stalk-color-above-ring')]

# %%
# Abeer Ghonaim 
# When i select the top 9 features

X =mushroom_Cleaned.iloc[:,[3,7,19,18,8,6,1,20,9]]# The number of feature will give a good accuracy
Y =mushroom_Cleaned["class"]

# 2- invoke the method
GNB = GaussianNB()

# 3- Train Naive Bayes Classifer
GNB = GNB.fit(X,Y)

# 4- Predict the response for train dataset
Predictions = GNB.predict(X)

# 5- To evaluate the Naive Bayes is to use cross-validation
output = cross_validate(GNB, X, Y, scoring="neg_mean_squared_error", cv=10, return_estimator =True)
naive_bayes_classif_scores = np.sqrt(-output["test_score"])

display_scores(naive_bayes_classif_scores)    

# x and y train
X=mushroom_Cleaned.iloc[:,[3,7,19,18,8,6,1,20,9]]# The number of feature will give a good accuracy
Y=mushroom_Cleaned["class"]

gussian = GaussianNB()
gussian.fit(X,Y) # train step
train_Y_pred = cross_val_predict(gussian, X, Y, cv=10) 
print("1) Accuracy:",  accuracy_score(Y, train_Y_pred))
print("2) Confusion matrix \n", confusion_matrix(Y, train_Y_pred))
print("3) Precision" , precision_score(Y, train_Y_pred, average = 'weighted'))
print("4) Recall" , recall_score(Y, train_Y_pred, average = 'weighted'))
# Out:
# Scores: [0.30382181 0.31622777 0.29088724 0.31378582 0.2987152  0.29612887
#  0.34194017 0.28284271 0.31622777 0.28845265]
# Mean: 0.3049029990008763
# Standard deviation: 0.01666526896285599
# 1) Accuracy: 0.9067548853669796
# 2) Confusion matrix
#  [[3174  192]
#  [ 414 2719]]
# 3) Precision 0.9084432979972968
# 4) Recall 0.9067548853669796

# %%
# Abeer Ghonaim
# 1- get X and Y from the dataset
#X =mushroom_Cleaned['bruises%3F','gill-size', 'spore-print-color', 'ring-type']#
X =mushroom_Cleaned.iloc[:,0:10]# The number of feature will give a good accuracy
Y =mushroom_Cleaned["class"]

# 2- invoke the method
GNB = GaussianNB()

# 3- Train Naive Bayes Classifer
GNB = GNB.fit(X,Y)

# 4- Predict the response for train dataset
Predictions = GNB.predict(X)

# 5- To evaluate the Naive Bayes is to use cross-validation
output = cross_validate(GNB, X, Y, scoring="neg_mean_squared_error", cv=10, return_estimator =True)
naive_bayes_classif_scores = np.sqrt(-output["test_score"])

display_scores(naive_bayes_classif_scores)    

# x and y train
X=mushroom_Cleaned.iloc[:,0:10]# The number of feature will give a good accuracy
Y=mushroom_Cleaned["class"]

gussian = GaussianNB()
gussian.fit(X,Y) # train step
train_Y_pred = cross_val_predict(gussian, X, Y, cv=10) 
print("1) Accuracy:",  accuracy_score(Y, train_Y_pred))
print("2) Confusion matrix \n", confusion_matrix(Y, train_Y_pred))
print("3) Precision" , precision_score(Y, train_Y_pred, average = 'weighted'))
print("4) Recall" , recall_score(Y, train_Y_pred, average = 'weighted'))
# Out:
# Scores: [0.2689009  0.27174649 0.26311741 0.2689009  0.26311741 0.24806947
#  0.3063432  0.26017745 0.2773501  0.28306054]
# Mean: 0.2710783846272967
# Standard deviation: 0.014870902345100774
# 1) Accuracy: 0.9262963532851208
# 2) Confusion matrix
#  [[3222  144]
#  [ 335 2798]]
# 3) Precision 0.9276257472042664
# 4) Recall 0.9262963532851208

# %%
# support vector machine 
from sklearn import svm
X=mushroom_Cleaned.iloc[:,0:8]# The number of feature will give a good accuracy
Y=mushroom_Cleaned["class"]
SVM = svm.SVC()
SVM.fit(X, Y)
train_Y_pred = cross_val_predict(SVM, X, Y, cv=10) 
#clf.predict()
#SVC()

print("1) Accuracy:",  accuracy_score(Y, train_Y_pred))
print("2) Confusion matrix \n", confusion_matrix(Y, train_Y_pred))
print("3) Precision" , precision_score(Y, train_Y_pred, average = 'weighted'))
print("4) Recall" , recall_score(Y, train_Y_pred, average = 'weighted'))
# Out:
# 1) Accuracy: 0.9815356208647484
# 2) Confusion matrix
#  [[3330   36]
#  [  84 3049]]
# 3) Precision 0.9816311570507029
# 4) Recall 0.9815356208647484

# %% [markdown]
# ### <font color=##6d5b57> 3. Random forest classifier - Roaa Alharthi</font>

# %%
from sklearn.ensemble import RandomForestClassifier

X = mushroom_Cleaned.drop('class',axis=1)
Y = mushroom_Cleaned['class']

   # Create for loop with the RFE object and rank each pixel
for i in range (1,23):
    rfc = RandomForestClassifier(max_depth=6, random_state=42)
    rfe = RFE(estimator=rfc, n_features_to_select=i, step=1)
    rfe.fit(X, Y)

    # Make the prediction and evaluate
    prediction=rfe.predict(X)
    Accuracy= accuracy_score(Y,prediction)

    print("Number of selected features:",rfe.n_features_,"accurecy",Accuracy)
                                                                                     # Roaa AlHarthi
# Out:
# Number of selected features: 1 accurecy 0.9850746268656716
# Number of selected features: 2 accurecy 0.9944606862594245
# Number of selected features: 3 accurecy 0.9944606862594245
# Number of selected features: 4 accurecy 0.9941529466071704
# Number of selected features: 5 accurecy 0.9941529466071704
# Number of selected features: 6 accurecy 0.9941529466071704
# Number of selected features: 7 accurecy 1.0
# Number of selected features: 8 accurecy 1.0
# Number of selected features: 9 accurecy 1.0
# Number of selected features: 10 accurecy 1.0
# Number of selected features: 11 accurecy 1.0
# Number of selected features: 12 accurecy 1.0
# Number of selected features: 13 accurecy 1.0
# Number of selected features: 14 accurecy 1.0
# Number of selected features: 15 accurecy 1.0
# Number of selected features: 16 accurecy 1.0
# Number of selected features: 17 accurecy 1.0
# Number of selected features: 18 accurecy 1.0
# Number of selected features: 19 accurecy 1.0
# ...

# %%
from sklearn.ensemble import RandomForestClassifier # Import Random forest Classifier
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation
from sklearn.model_selection import cross_val_predict,cross_validate,cross_val_score

# 1- get X and Y from the dataset
X_train=mushroom_Cleaned.iloc[:,0:8]# The number of feature will give a good accuracy
y_train=mushroom_Cleaned["class"]

# 2- invoke the method
rfc = RandomForestClassifier(max_depth=6, random_state=42)

# 3- Train Random forest Classifer
rfc = rfc.fit(X_train,y_train)

# 4- Predict the response for train dataset
Predictions = rfc.predict(X_train)

# 5- To evaluate the Random forest model is to use cross-validation
forest_clf_multi_scores=cross_val_score(rfc, X_train, y_train, cv=10, scoring="accuracy")


display_scores(forest_clf_multi_scores)                                        # Roaa AlHarthi
# Out:
# Scores: [0.99230769 0.98615385 0.99230769 0.98615385 0.98307692 0.98923077
#  0.98769231 0.99384615 0.98461538 0.99075501]
# Mean: 0.9886139623088777
# Standard deviation: 0.0034529531463144436

# %%
y_train_pred = cross_val_predict(rfc, X_train, y_train, cv=10)
scores = cross_val_score(rfc, X_train,y_train, cv=10, scoring="accuracy")
print("Accuracy of each fold :\n",scores)
print("Mean of accuracy :",scores.mean()) 
print("Confusion matrix:\n",metrics.confusion_matrix(y_train,y_train_pred))
print("Recall: ",metrics.recall_score(y_train,y_train_pred,average='weighted'))
print("Precision: ",metrics.precision_score(y_train,y_train_pred,average='weighted'))
                                                                               # Roaa AlHarthi
# Out:
# Accuracy of each fold :
#  [0.99230769 0.98615385 0.99230769 0.98615385 0.98307692 0.98923077
#  0.98769231 0.99384615 0.98461538 0.99075501]
# Mean of accuracy : 0.9886139623088777
# Confusion matrix:
#  [[3328   38]
#  [  36 3097]]
# Recall:  0.9886136328665949
# Precision:  0.9886140697542214

# %% [markdown]
# ### <font color=#6d5b57>  <span>&#183;</span> Comparison of models’ performance.</font>

# %%
classifiers=['DTC','GNB', 'RFC']
Accuracy = [0.9987,0.9262,0.9886]
plt.bar(classifiers,Accuracy)
plt.show()

# %% [markdown]
# ### <font color= blue >As we can see from the bar, the decision tree and random forest are close in the accuracy, but tree has higher performance. The naive bayes compare to them has lower accuracy. So we will chose Decision Tree to apply it on the test set. </font>

# %% [markdown]
# # <font color=#4D4435>Evaluating on the test set:</font>

# %%
# Reload the test mushroom dataset
mushroomTest_cleaned = pd.read_csv("C:/Users/abooo/Desktop/CPIT 440 WLab/test_cleand.csv") 
mushroomTest_cleaned
# Out:
#       cap-shape  cap-surface  cap-color  bruises%3F  odor  gill-attachment  \
# 0             1            2          3           1     4                1
# 1             1            3          8           1     2                1
# 2             1            0          8           1     6                1
# 3             2            3          7           1     4                1
# 4             1            0          9           1     4                1
# 5             2            0          8           0     0                1
# 6             2            2          9           0     0                1
# 7             2            0          0           1     6                1
# 8             2            0          0           0     6                1
# 9             2            3          8           0     7                1
# 10            2            2          9           1     4                1
# ...

# %%
# Decision Tree Classifier 
test_X = mushroomTest_cleaned.iloc[:,0:10]
test_Y = mushroomTest_cleaned["class"]

final_predictions = tree.predict(test_X)
print("1) Accuracy:",  accuracy_score(test_Y, final_predictions))
print("2) Confusion matrix \n", confusion_matrix(test_Y, final_predictions))
print("3) Precision" , precision_score(test_Y, final_predictions, average = 'weighted'))
print("4) Recall" , recall_score(test_Y, final_predictions, average = 'weighted'))
# Out:
# 1) Accuracy: 0.8787692307692307
# 2) Confusion matrix
#  [[646 196]
#  [  1 782]]
# 3) Precision 0.9026328391173405
# 4) Recall 0.8787692307692307

# %%
# Randomm Forest Classifier
test_X = mushroomTest_cleaned.iloc[:,0:8]
test_Y = mushroomTest_cleaned["class"]

final_predictions = rfc.predict(test_X)
print("1) Accuracy:",  accuracy_score(test_Y, final_predictions))
print("2) Confusion matrix \n", confusion_matrix(test_Y, final_predictions))
print("3) Precision" , precision_score(test_Y, final_predictions, average = 'weighted'))
print("4) Recall" , recall_score(test_Y, final_predictions, average = 'weighted'))
# Out:
# 1) Accuracy: 0.9821538461538462
# 2) Confusion matrix
#  [[818  24]
#  [  5 778]]
# 3) Precision 0.982432705972241
# 4) Recall 0.9821538461538462

# %%
# Gussian Naive Bayes Classifier
test_X = mushroomTest_cleaned.iloc[:,0:10]
test_Y = mushroomTest_cleaned["class"]

final_predictions = GNB.predict(test_X)
#(1) Accuracy
accuracy_score(test_Y, final_predictions)
print("1) Accuracy:",  accuracy_score(test_Y, final_predictions))
print("2) Confusion matrix \n", confusion_matrix(test_Y, final_predictions))
print("3) Precision" , precision_score(test_Y, final_predictions, average = 'weighted'))
print("4) Recall" , recall_score(test_Y, final_predictions, average = 'weighted'))
# Out:
# 1) Accuracy: 0.9273846153846154
# 2) Confusion matrix
#  [[815  27]
#  [ 91 692]]
# 3) Precision 0.9298614880623004
# 4) Recall 0.9273846153846154

# %% [markdown]
# ### <font color= blue > First, we expect that Decision Tree will have the highest accuracy on the test set, but when we apply the others, we found that Random Forest is better.

# %%
from sklearn import svm
X=mushroomTest_cleaned.iloc[:,0:8]# The number of feature will give a good accuracy
Y=mushroomTest_cleaned["class"]
SVM = svm.SVC()
SVM.fit(X, Y)
train_Y_pred = SVM.predict(X)
#clf.predict()
#SVC()

print("1) Accuracy:",  accuracy_score(Y, train_Y_pred))
print("2) Confusion matrix \n", confusion_matrix(Y, train_Y_pred))
print("3) Precision" , precision_score(Y, train_Y_pred, average = 'weighted'))
print("4) Recall" , recall_score(Y, train_Y_pred, average = 'weighted'))
# Out:
# 1) Accuracy: 0.9636923076923077
# 2) Confusion matrix
#  [[816  26]
#  [ 33 750]]
# 3) Precision 0.9637154145988797
# 4) Recall 0.9636923076923077
